# %%
#Question:1
prog_lang=["Python","Java","Java Script","C++", "SQL","PHP"]
print(len(prog_lang))
# Out:
# 6

# %%
#Question:2
num=[2,3,5,7,9,11,13,15]
print(sum(num))
# Out:
# 65

# %%
#Question:3
num1=[2,3,7,84,7,-3]
print(max(num1))
# Out:
# 84

# %%
#Question:4
a=[1,1,2,3,5,8,13,21,34,5,89]
for num in a:
    if num<5:
        print(num)
# Out:
# 1
# 1
# 2
# 3
